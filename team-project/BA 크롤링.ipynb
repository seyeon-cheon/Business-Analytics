# %%
import os
import sys
import urllib.request
import json
import pandas as pd
import csv

# %%
client_id = "sjLpa9C1xgZo0gqKTL3Z"
client_secret = "FXyffvjqWF"

encText = urllib.parse.quote("스터디 카페")

# %%
import requests
from urllib.parse import urlparse
 
keyword = "스터디카페"
url = "https://openapi.naver.com/v1/search/blog?query=" + keyword
result = requests.get(urlparse(url).geturl(),
                      headers={"X-Naver-Client-Id": client_id,
                             "X-Naver-Client-Secret":client_secret})
json_obj = result.json()
print(json_obj)
type(json_obj)
# Out:
# {'lastBuildDate': 'Fri, 30 Oct 2020 23:34:46 +0900', 'total': 534215, 'start': 1, 'display': 10, 'items': [{'title': '다산독서실 어려운 문제도 술술 풀릴 것 같은 초심<b>스터디카페</b>', 'link': 'https://blog.naver.com/cycbooks?Redirect=Log&logNo=222123243543', 'description': '아무래도 집에서는 집중이 잘 안 돼서 다산독서실을 알아보던 중에 초심<b>스터디카페</b> 다산지금점을... 스터디존은 카페존과 분리되어 운영되는 곳이에요. 방음벽이 설치되어 있어서 조용하게 공부를 하기에 딱... ', 'bloggername': '소리북스 블로그', 'bloggerlink': 'https://blog.naver.com/cycbooks', 'postdate': '20201022'}, {'title': '안산 <b>스터디카페</b> 밝은 공간만큼 집중력 끝판왕!', 'link': 'https://blog.naver.com/l_lli?Redirect=Log&logNo=222116487795', 'description': '안산 <b>스터디카페</b>가 생겨 방문하게 되었어요. 도서관이나 독서실보다 좀더 자유스러운 카페에서... 그룹 스터디를 할 때나, 특정 공간을 빌려 회의를 진행 시 편리 하게 되어 있었어요. 과외나 독서모임 등 소규모... ', 'bloggername': '룩플레이스', 'bloggerlink': 'https://blog.naver.com/l_lli', 'postdate': '20201015'}, {'title': '신방동<b>스터디카페</b> 카공족 마음에 쏙 드는 카페를 찾았어요!', 'link': 'https://blog.naver.com/yeechi?Redirect=Log&logNo=222127795089', 'description': '신방동<b>스터디카페</b>의 장점은 자신에게 잘 맞는 환경을 선택해 공부할 수 있다는 점인 것 같아요. 카페존과 소굴방 외에도 스터디존이라는 공간이 있는데요. 여기는 도서관처럼 조용히 공부에만 집중할 수 있는... ', 'bloggername': '즐거운 나의 집', 'bloggerlink': 'https://blog.naver.com/yeechi', 'postdate': '20201027'}, {'title': '<b>스터디카페</b>창업 걱정이 앞선다면', 'link': 'https://blog.naver.com/wlsdkwns?Redirect=Log&logNo=222107541671', 'description': '바로 그루스터디 <b>스터디카페</b>창업 입니다. 그루의 본사만의 강점이자 장점은 성공요인으로 봐도 무방하며 다양하고 많은 점들을 지니고 있어 이렇게 알려드립니다. 그 중 대표적으로는 가맹관리 입니다. 어느... ', 'bloggername': '슬기로운 취미생활 :-)', 'bloggerlink': 'https://blog.naver.com/wlsdkwns', 'postdate': '20201005'}, {'title': '칠곡3지구 <b>스터디카페</b> 괜찮은 곳 찾았어요', 'link': 'https://blog.naver.com/klawier7?Redirect=Log&logNo=222123411957', 'description': '너무 어두운 곳에서는 눈이 피곤해서 집중을 잘하지 못하는 저여서 만족스럽게 스터디를 이어갈 수 있었죠. 여기가 칠곡3지구 <b>스터디카페</b>의 카페테리아 공간인데요. 이곳에서는 같이 하는 사람들과 적당한... ', 'bloggername': '아직알수없다는스릴넘치는이야기', 'bloggerlink': 'https://blog.naver.com/klawier7', 'postdate': '20201022'}, {'title': '무인<b>스터디카페</b> 요즘 시대에 딱 맞는 창업 아이템!', 'link': 'https://blog.naver.com/kim779944?Redirect=Log&logNo=222103096336', 'description': 'ㅎㅎ 또 무인<b>스터디카페</b>라도 있을 건 다 있어요. 공부하다 힘들면 잠시 쉬어갈 수 있도록 안마존이 있고 당 보충할 수 있도록 셀프바도 있답니다. 다양한 스터디룸까지 마련돼있어서 학생, 직장인, 동호회 등... ', 'bloggername': '비알모', 'bloggerlink': 'https://blog.naver.com/kim779944', 'postdate': '20200929'}, {'title': '창원 <b>스터디카페</b> 학습을 위한 최적의 공간 비젼<b>스터디카페</b>', 'link': 'https://blog.naver.com/eunhwanimaaa?Redirect=Log&logNo=222103964073', 'description': '[ 창원 비젼<b>스터디카페</b> :: 카페 룸 / 포커스 룸 ] 스터디 룸 외에 비젼 카페와 비젼 포커스로 룸이 2개로 나누어졌어요. 룸마다 개별 사물함이 위치해있었는데 사물함은 2주권 6,000원 / 4주권 10,000원으로 이용할 수... ', 'bloggername': '#바그나로그', 'bloggerlink': 'https://blog.naver.com/eunhwanimaaa', 'postdate': '20200930'}, {'title': '[수원] 경희대<b>스터디카페</b> 베스트 알아봤어요!', 'link': 'https://blog.naver.com/baisj?Redirect=Log&logNo=222111225693', 'description': '스터디앤카페엘로 경희대학교랑 가까움, 밝은 분위기 3. 어라운드<b>스터디카페</b> 경희대학교 인근, 밝은 조명 4. 르하임<b>스터디카페</b> 경희대와는 조금 거리 있음, 책상 넓음 5. 초심<b>스터디카페</b> 경희대와는 조금 거리... ', 'bloggername': '두두의 일기장', 'bloggerlink': 'https://blog.naver.com/baisj', 'postdate': '20201009'}, {'title': '신촌 <b>스터디카페</b> 포텐<b>스터디카페</b> 솔직후기', 'link': 'https://blog.naver.com/snowrun?Redirect=Log&logNo=222116876042', 'description': '얼마만의 카페탐방인지.....ㅠㅠ 지난달엔 하나도 못썼더라고요...하ㅜㅡㅜ 감격의 신촌 <b>스터디카페</b>... 스터디룸도 두 공간이 있는데요. 1시간 4인기준 6천원이고 한명씩 추가될 시 천원 추가돼요. 시간제... ', 'bloggername': '핸잉이의 하늘꿈_', 'bloggerlink': 'https://blog.naver.com/snowrun', 'postdate': '20201016'}, {'title': '랭<b>스터디카페</b>와 커피랑도서관', 'link': 'https://blog.naver.com/shopbuilder?Redirect=Log&logNo=222125795600', 'description': '커피랑도서관,랭스터디와는 아무 관계없는 이용자일 뿐이다 이 포스팅을 랭<b>스터디카페</b>에서 작성하고... 라떼,카푸치노,요거트,아이스티 등 카페만큼의 다양한 메뉴가 있다 음료이용이 필수는 아니지만... ', 'bloggername': '로스팅맨의 커피,부동산이야기', 'bloggerlink': 'https://blog.naver.com/shopbuilder', 'postdate': '20201025'}]}
# dict

# %%
def call(keyword, start):
    encText = urllib.parse.quote(keyword)
    url = "https://openapi.naver.com/v1/search/blog?query="+encText+"&sort=sim&display=100&start="+str(start)
    result = requests.get(url=url, headers={"X-Naver-Client-Id":client_id,"X-Naver-Client-Secret":client_secret})
    print(result)  # Response [200]
    return result.json()

# %%
#call("스터디카페", 10)

# %%
def results(keyword):
    list = []
    for num in range(0,10):
        list = list + call(keyword, num * 110 + 1)['items'] 
    return list

# %%
listt = []
result = results('스터디카페')
listt = listt+result

file = open('studycafe_blog.json','w+')
file.write(json.dumps(listt))


df = pd.read_json('studycafe_blog.json')
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
import re

def clean_html(x):
    x = re.sub("\&\w*\;","",x)
    x = re.sub("<.*?>","",x)
    return x

# %%
df['title'] = df['title'].apply(lambda x: clean_html(x))
df['description'] = df['description'].apply(lambda x: clean_html(x))

# %%
df

# %%
#df.to_csv('studycafe1.csv',encoding='cp949')
df.to_csv('crawling_blog.csv',encoding='utf-8-sig',index=False)

# %% [markdown]
# ### 모어댄 스터디카페

# %%
import requests
from urllib.parse import urlparse
 
keyword = '"모어댄 스터디카페"'
url = "https://openapi.naver.com/v1/search/blog?query=" + keyword
result = requests.get(urlparse(url).geturl(),
                      headers={"X-Naver-Client-Id": client_id,
                             "X-Naver-Client-Secret":client_secret})
json_obj = result.json()
print(json_obj)
type(json_obj)
# Out:
# {'lastBuildDate': 'Sat, 31 Oct 2020 09:33:31 +0900', 'total': 22, 'start': 1, 'display': 10, 'items': [{'title': '낙성대<b>스터디</b><b>카페</b>추천!❣ 새로생긴 <b>모어댄스터디카페</b>에... ', 'link': 'https://blog.naver.com/tnwlslol?Redirect=Log&logNo=222097412366', 'description': '춥더라구요 ㅜㅡㅜ 너무추워서 중간에 나온점도 있어용...ㅋㅋ 낙성대 인헌시장근처 <b>스터디</b><b>카페</b>를 찾으신다면 <b>모어댄 스터디카페</b> 추천드려요 !!! #낙성대<b>스터디</b><b>카페</b> #<b>모어댄스터디카페</b> #낙성대<b>스터디</b><b>카페</b>추천', 'bloggername': '쑤코치의 일상스토리❣', 'bloggerlink': 'https://blog.naver.com/tnwlslol', 'postdate': '20200923'}, {'title': '낙성대 <b>스터디</b><b>카페</b> <b>모어댄</b>에서 공부하쟈!', 'link': 'https://blog.naver.com/0415carrot?Redirect=Log&logNo=221999023212', 'description': "낙성대 <b>스터디</b><b>카페</b> <b>모어댄</b>에서 공부해용 <b>모어댄스터디카페</b> 주소: 서울시 관악구 봉천동 196-45 2층 영업시간: 24시간 전화: ***-****-**** (카카오플러스친구도 있어요. '<b>모어댄스터디카페</b>'검색해서 문의도... ", 'bloggername': '당근냥의여행이야기', 'bloggerlink': 'https://blog.naver.com/0415carrot', 'postdate': '20200613'}, {'title': '<b>모어댄 스터디카페</b> 금호점 내부 시설안내', 'link': 'https://blog.naver.com/morethankh?Redirect=Log&logNo=222095782443', 'description': '금호동스터디카페 #<b>모어댄스터디카페</b> #<b>모어댄스터디카페</b>금호점 #Studywithme #스윗미 #금호역카페... ♥ 모어댄의 브랜드 아이덴티티에요 모어댄이라는 이름에 걸맞게 그 이상의 수준을 드리고자 컨셉부터... ', 'bloggername': '모어댄 스터디카페 금호점', 'bloggerlink': 'https://blog.naver.com/morethankh', 'postdate': '20200921'}, {'title': '낙성대<b>스터디</b><b>카페</b> 작지만 알찬 <b>모어댄스터디카페</b>를 소개합니다!', 'link': 'https://blog.naver.com/jjonjju?Redirect=Log&logNo=221920304678', 'description': '작지만 알찬 낙성대<b>스터디</b><b>카페</b> <b>모어댄스터디카페</b>를 소개합니다! 시끄러운 분위기로 본인의 <b>스터디</b>나 업무에 방해가 되었던 적이 있으신가요? 노트북 타이핑 소리로 주변사람들의 눈치를 본 적은 있지... ', 'bloggername': '끄적끄적 일상 은댕2★', 'bloggerlink': 'https://blog.naver.com/jjonjju', 'postdate': '20200421'}, {'title': '낙성대역 <b>모어댄스터디 카페</b> 작지만 이용하기 편리한 곳!!', 'link': 'https://blog.naver.com/guan-nuen744?Redirect=Log&logNo=221920356479', 'description': "또한 낙성대역 <b>모어댄스터디 카페</b>는 <b>스터디</b> <b>카페</b> 무인 솔루션인 '고스카'를 사용하는데요. 이 어플을 이용하시면 좌석을 사용하고 있는 내역도 한눈에 보이고 자리 이동도 가능해 좀 더 편리하게 이용하실 수... ", 'bloggername': 'Josh79', 'bloggerlink': 'https://blog.naver.com/guan-nuen744', 'postdate': '20200421'}, {'title': '<b>모어댄 스터디카페</b> 오픈소식', 'link': 'https://blog.naver.com/morethan_studycafe?Redirect=Log&logNo=221886048092', 'description': "<b>모어댄 스터디카페</b> 낙성대 1호점 2020 4/15 OPEN! <b>스터디</b>존(집중존) / 노트북존 운영 <b>스터디</b><b>카페</b> 바로 앞에 편의점, <b>카페</b>, 치안센터 '고스카'에서 핸드폰으로도 좌석 예약가능 고스카를 이용하는 다양한... ", 'bloggername': 'More Than Study Cafe', 'bloggerlink': 'https://blog.naver.com/morethan_studycafe', 'postdate': '20200402'}, {'title': '&quot;9월 중순 오픈예정&quot; - <b>모어댄 스터디카페</b> 금호점', 'link': 'https://blog.naver.com/morethankh?Redirect=Log&logNo=222074683729', 'description': '금호동스터디카페 #<b>모어댄스터디카페</b> #<b>모어댄스터디카페</b>금호점 #Studywithme #스윗미 #금호역카페... (현재 공사중이라 아래 사진은 모어댄 낙성대점 입니다. ^^) Previous image Next image 모어댄 스터디카페... ', 'bloggername': '모어댄 스터디카페 금호점', 'bloggerlink': 'https://blog.naver.com/morethankh', 'postdate': '20200829'}, {'title': '<b>모어댄</b> 고객이면 1:1 영어회화 1회 무료!', 'link': 'https://blog.naver.com/morethan_studycafe?Redirect=Log&logNo=222129148044', 'description': '#<b>모어댄스터디카페</b> #영어회화 #화상영어 #잉그올 #낙성대<b>스터디</b><b>카페</b> #낙성대독서실 #<b>스터디</b><b>카페</b> 안녕하세요, <b>모어댄</b>입니다. 커피할인과 더불어 이용 고객분들만을 위한 추가 제휴를 준비했습니다! 이번엔... ', 'bloggername': 'More Than Study Cafe', 'bloggerlink': 'https://blog.naver.com/morethan_studycafe', 'postdate': '20201028'}, {'title': '<b>모어댄</b> 환풍기 설치 (9/29)', 'link': 'https://blog.naver.com/morethan_studycafe?Redirect=Log&logNo=222098971494', 'description': '안녕하세요 <b>모어댄 스터디카페</b> 낙성대 1호점입니다. 화장실에는 환풍기 설치를 이미 완료했으며... <b>모어댄</b>의 부족한 점은 계속 보강해나갈 예정이오니 앞으로도 많은 기대 부탁드려요 :-)', 'bloggername': 'More Than Study Cafe', 'bloggerlink': 'https://blog.naver.com/morethan_studycafe', 'postdate': '20200925'}, {'title': '<b>모어댄</b> 신규 이벤트중!', 'link': 'https://blog.naver.com/morethan_studycafe?Redirect=Log&logNo=221935107608', 'description': '(카카오톡 &quot;<b>모어댄 스터디카페</b> 낙성대점&quot; 검색) 답변들을 살펴보는데 예상치도 못 한 부분들이 많더라구요~ 솔직한 피드백을 주시면 앞으로 더 나은 <b>모어댄</b>을 만 ...
# dict

# %%
def call(keyword, start):
    encText = urllib.parse.quote(keyword)
    url = "https://openapi.naver.com/v1/search/blog?query="+encText+"&sort=sim&display=100&start="+str(start)
    result = requests.get(url=url, headers={"X-Naver-Client-Id":client_id,"X-Naver-Client-Secret":client_secret})
    print(result)  # Response [200]
    return result.json()

# %%
def results(keyword):
    list = []
    for num in range(0,10):
        list = list + call(keyword, num * 110 + 1)['items'] 
    return list

# %%
listt = []
result = results('"모어댄 스터디카페"')
listt = listt+result

file = open('studycafe_morethan.json','w+')
file.write(json.dumps(listt))


df = pd.read_json('studycafe_morethan.json')
# print(df)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
import re

def clean_html(x):
    x = re.sub("\&\w*\;","",x)
    x = re.sub("<.*?>","",x)
    return x

# %%
df['title'] = df['title'].apply(lambda x: clean_html(x))
df['description'] = df['description'].apply(lambda x: clean_html(x))

# %%
df
# Out:
#                                  title  \
# 0      낙성대스터디카페추천!❣ 새로생긴 모어댄스터디카페에...
# 1                낙성대 스터디카페 모어댄에서 공부하쟈!
# 2                모어댄 스터디카페 금호점 내부 시설안내
# 3     낙성대스터디카페 작지만 알찬 모어댄스터디카페를 소개합니다!
# 4      낙성대역 모어댄스터디 카페 작지만 이용하기 편리한 곳!!
# ..                                 ...
# 185  낙성대스터디카페 깔끔하면서 모던함이 있는 모어댄스터디카페!!
# 186                          모어댄 내부 사진
# 187     모어댄스터디카페,작지만 알찬 곳!낙성대스터디카페...
# 188   낙성대역스터디카페가 있는 모어댄스터디카페에서 공부를...
# 189         낙성대스터디카페 모어댄스터디카페 작지만 알찬곳!
#
#                                                   link  \
# 0    https://blog.naver.com/tnwlslol?Redirect=Log&l...
# 1    https://blog.naver.com/0415carrot?Redirect=Log...
# 2    https://blog.naver.com/morethankh?Redirect=Log...
# 3    https://blog.naver.com/jjonjju?Redirect=Log&lo...
# 4    https://blog.naver.com/guan-nuen744?Redirect=L...
# ..                                                 ...
# 185  https://blog.naver.com/sem4404?Redirect=Log&lo...
# 186  https://blog.naver.com/morethan_studycafe?Redi...
# 187  https://blog.naver.com/dudfks0243?Redirect=Log...
# 188  https://blog.naver.com/dlqhal0213?Redirect=Log...
# 189  https://blog.naver.com/hyeseon6803?Redirect=Lo...
#
#                                            description           bloggername  \
# 0    춥더라구요 ㅜㅡㅜ 너무추워서 중간에 나온점도 있어용...ㅋㅋ 낙성대 인헌시장근처 스...           쑤코치의 일상스토리❣
# 1    낙성대 스터디카페 모어댄에서 공부해용 모어댄스터디카페 주소: 서울시 관악구 봉천동 ...             당근냥의여행이야기
# 2    금호동스터디카페 #모어댄스터디카페 #모어댄스터디카페금호점 #Studywithme #...         모어댄 스터디카페 금호점
# 3    작지만 알찬 낙성대스터디카페 모어댄스터디카페를 소개합니다! 시끄러운 분위기로 본인의...          끄적끄적 일상 은댕2★
# 4    또한 낙성대역 모어댄스터디 카페는 스터디 카페 무인 솔루션인 '고스카'를 사용하는데...                Josh79
# ..                                                 ...                   ...
# 185  그래서 그런지 주변에 스터디카페가 두어군데는 보이는것 같아요~ 깔끔하면서 모던함이 ...             예진&예나의 하루
# 186  안녕하세요, 모어댄 스터디카페에요! 무료쿠폰 50매 이벤트가 순삭을 당했...! 많...  More Than Study Cafe
# 187  :) 모어댄스터디카페는 스터디카페 무인 솔루션인 코스카를 사용하고 있다고 하는데요,...       dudfks0243님의블로그
# 188  모어댄스터디카페는 스터디카페 무인 솔루션인 '고스카'를 사용하고있습니다. 고스카 어...                 지유서준맘
# 189  조용히 집중할수 있는 집중존이랑 노트북 사용 가능한 노트북존을 분리 운영하고 있어서...                    ㅂㄺ
#
#                                    bloggerlink  postdate
# 0              https://blog.naver.com/tnwlslol  20200923
# 1            https://blog.naver.com/0415carrot  20200613
# 2            https://blog.naver.com/morethankh  20200921
# 3               https://blog.naver.com/jjonjju  20200421
# 4          https://blog.naver.com/guan-nuen744  20200421
# ..                                         ...       ...
# 185             https://blog.naver.com/sem4404  20200421
# 186  https://blog.naver.com/morethan_studycafe  20200427
# 187          https://blog.naver.com/dudfks0243  20200421
# 188          https://blog.naver.com/dlqhal0213  20200421
# 189         https://blog.naver.com/hyeseon6803  20200421
#
# [190 rows x 6 columns]

# %%
#df.to_csv('studycafe1.csv',encoding='cp949')
df.to_csv('crawling_morethan.csv',encoding='utf-8-sig',index=False)

# %% [markdown]
# ### 카페

# %%
def call(keyword, start):
    encText = urllib.parse.quote(keyword)
    url = "https://openapi.naver.com/v1/search/cafearticle.json?query="+encText+"&sort=sim&start="+str(start)
    result = requests.get(url=url, headers={"X-Naver-Client-Id":client_id,"X-Naver-Client-Secret":client_secret})
    print(result)  # Response [200]
    return result.json()

# %%
#call('스터디카페',10)

# %%
def results(keyword):
    list = []
    for num in range(0,10):
        list = list + call(keyword, num * 110 + 1)['items'] 
    return list

# %%
results('스터디카페')
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# [{'title': '그냥 느낌으로 적는 <b>스터디카페</b> 동향',
#   'link': 'http://cafe.naver.com/jihosoccer123/619343',
#   'description': '안녕하세요 저는 <b>스터디카페</b>를 운영하는 점주 입니다. 3군대를 운영하다 하나를 매도 했습니다. 첫 시작이 2년전이라, 디테일하게 계산은 하지 않았지만 이미 모든 매장의 투자비는 회수를 하고, 순수 수익 구간에 있습니다.... ',
#   'cafename': '아프니까 사장이다 [소상공인·자영업...',
#   'cafeurl': 'https://cafe.naver.com/jihosoccer123'},
#  {'title': '<b>스터디카페</b> 자리 어떨까요',
#   'link': 'http://cafe.naver.com/jihosoccer123/618886',
#   'description': '<b>스터디카페</b> 하나해볼까 생각중입니다 수원YMCA 가 위치한 건물이 철거되고 망포역센타프라자 라고 지하2층~지상7층 건물이 생깁니다 지금 철거하려고 가림막 쳐놓은거 지나가면서 볼수 있구요 망포역 바로앞이기도하고... ',
#   'cafename': '아프니까 사장이다 [소상공인·자영업...',
#   'cafeurl': 'https://cafe.naver.com/jihosoccer123'},
#  {'title': '<b>스터디카페</b>',
#   'link': 'http://cafe.naver.com/jookjeonmom/1166845',
#   'description': '예비 중딩아이가 <b>스터디카페</b>가서 공부하고 싶다고 하네요. 학원을 하나도 안다니는 자유로운 아이입니다^^ 그나마 다니던 영어학원도 이제 안녕~ 하고 혼자 문제집사서 풀고, 수학학원은 한번 다녀본적없고 그냥 혼자 해요.... ',
#   'cafename': '죽전 마북 보정 엄마들의 카페',
#   'cafeurl': 'https://cafe.naver.com/jookjeonmom'},
#  {'title': '11자 <b>스터디카페</b>',
#   'link': 'http://cafe.naver.com/dongtantwomom/1319200',
#   'description': '오픽 화상수업 들으러 가려는데 영어 스피킹 정도 작게 할수있는 <b>스터디카페</b>가 있을까요? 아님 일반 커피숍을 가야하나요... <b>스터디카페</b>를 한번도 안가봐서 어느정도 조용한지 모르겠어요ㅠ',
#   'cafename': '동탄2신도시맘 ♣ 동탄투맘 모여요~ [...',
#   'cafeurl': 'https://cafe.naver.com/dongtantwomom'},
#  {'title': '<b>스터디카페</b>에서 공부하는데...',
#   'link': 'http://cafe.naver.com/polstudy/2887484',
#   'description': '누가 옳고 그름의 문제는 아니라고 생각하지만 집중하다가 이런 일 생기니 마음이 싱숭생숭합니다 여러분들은 어떻게 생각하시나요 +참고로 <b>스터디카페</b>가 커서 소리가 울리는 구조이긴 하지만 그분과는 바로 옆자리는... ',
#   'cafename': '경꿈사★경찰공무원을 꿈꾸는 사람들/...',
#   'cafeurl': 'https://cafe.naver.com/polstudy'},
#  {'title': '오랜만에 <b>스터디카페</b>에 왔어요!',
#   'link': 'http://cafe.naver.com/mbticafe/372300',
#   'description': '한동안 신나는 분위기를 맛보려고 <b>스터디카페</b>가 아닌 일반 카페가서 수업을 들었는데 조금씩 종강에 다가가면서 고요하고 쾌적한 곳으로 가고 싶더라구요. 그래서 오늘 오랜만에 <b>스터디카페</b>에 오게 되었습니다! 잠깐... ',
#   'cafename': 'MBTI &amp; Health 심리 카페',
#   'cafeurl': 'https://cafe.naver.com/mbticafe'},
#  {'title': '여성전용 <b>스터디카페</b>?',
#   'link': 'http://cafe.naver.com/suhui/24246604',
#   'description': '평소 가던데와 다른 <b>스터디카페</b>에서 집에 가려 하는데 가는 길에 보니까 그 건물 지하 1층에 여성전용 <b>스터디카페</b>가 있던거 있죠? 이로써 같은 건물에 독서실 1개, 일반 <b>스터디카페</b> 1개, 여성 <b>스터디카페</b> 1개가 있는데...... ',
#   'cafename': '수만휘-수능날만점시험지를휘날리자★...',
#   'cafeurl': 'https://cafe.naver.com/suhui'},
#  {'title': '<b>스터디카페</b> 창업 할게 정말 많네요',
#   'link': 'http://cafe.naver.com/smart9619/21217',
#   'description': '2000년 초반에만 하더라도 꽉막힌 숨막힐듯 조용한 독서실에서 모두 수능공부를 했었는데요^^ 지금은 밝은 조명과 깨끗하고 화사한 공간에서 럭셔리하게 공부를 하는 <b>스터디카페</b>가 많이 생겼어요! 또 코로나포스트... ',
#   'cafename': '제공모-수익형블로그모임/CPA애드센스...',
#   'cafeurl': 'https://cafe.naver.com/smart9619'},
#  {'title': '방역 철저한 <b>스터디카페</b> 어디있을까요?',
#   'link': 'http://cafe.naver.com/dongtanmom/5103264',
#   'description': '아이가 자격 시험을 앞두고 있어 동탄에 뭐 <b>스터디카페</b>에 다니고 있는데 오늘은 갔다가 바로 왔더라구요. 계속 한 아주머니가 마스크를 미착용하고 내부에서 취식을 하고 기침을 하는데 얘기해도 소용없고 <b>스터디카페</b>... ',
#   'cafename': '◆동탄맘들 모여라',
#   'cafeurl': 'https://cafe.naver.com/dongtanmom'},
#  {'title': '<b>스터디카페</b> 투표좀 해주세요',
#   'link': 'http://cafe.naver.com/moonhistory/92146',
#   'description': "1 1).집에서 10분거리 (도보) 2)시험기간에 중고딩들 생각보다 많음 ' 3)떠들면 소리가 바로 들림 4)프린트비용은 무료 5)교실형 자유석 6)프리미엄 <b>스터디카페</b>인데, 먹을거같은거 제공이 전혀없음 2 1)집에서 도보로... ",
#   'cafename': '한국사는 문동균',
#   'cafeurl': 'https://cafe.naver.com/moonhistory'},
#  {'title': '서울 노원구 중계동 <b>스터디카페</b> 양도',
#   'link': 'http://cafe.naver.com/jihosoccer123/610768',
#   'description': '주소 ▶ 서울특별시 노원구 중계동 은행사거리 업종 ▶ <b>스터디카페</b> 층수 ▶ 지하 1층 면적 ▶ 106평 보증금 ▶ 8000만원 임대료 ▶ 500만원 권리금 ▶ 협의 총금액 ▶ 협의 이름 ▶ 홍순일 근무하는 직원의 수 ▶ 1명... ',
#   'cafename': '아프니까 사장이다 [소상공인·자영업...',
#   'cafeurl': 'https://cafe.naver.com/jihosoccer123'},
#  {'title': '추석연휴 공부는 스카이<b>스터디카페</b>에서~~',
#   'link': 'http://cafe.naver.com/1sejongcity/1022679',
#   'description': '긴연휴 조용히 혼자만의 집중할수있는 시간이 필요하시다면 스카이<b>스터디카페</b>는 어떠세요~~ 추석연휴 전 기간 정상영업합니다. 24시간 연중무휴~~ 아름동 1290번지 청솔빌딩 2층. 2020년 힘든 코로나 기간동안 함께... ',
#   'cafename': '세종시닷컴',
#   'cafeurl': 'https://cafe.naver.com/1sejongcity'},
#  {'title': '창원시 중동 <b>스터디카페</b> 추천~',
#   'link': 'http://cafe.naver.com/goldschools/646799',
#   'description': '창원 중동쪽으로 <b>스터디카페</b>나 칸막이 없는?독서실 아시면 추천 해주세요 아는데가 없네요 제가 어릴때부터 꽉 막힌 데서 공부하는게 집중이 안되는데 ㅋ... 학교나 학원처럼 좀 트여있고 개방된게 오히려 집중하기가... ',
#   'cafename': '특목고갈사람모여라(외고과학고영재고...',
#   'cafeurl': 'https://cafe.naver.com/goldschools'},
#  {'title': '<b>스터디카페</b> 가보신분 있나요?',
#   'link': 'http://cafe.naver.com/anbabmo/74433',
#   'description': '<b>스터디 카페</b> 가보신분 있나요? 요즘 저희 아이가 <b>스터디카페</b> 가고싶다고 등록해달라고 하는데 어때요? 괜찮아요?',
#   'cafename': '▒안밥모▒ 밥 안먹는 아이를 둔 엄마...',
#   'cafeurl': 'https://cafe.naver.com/anbabmo'},
#  {'title': '평내동에 <b>스터디카페</b> 추천좀요!',
#   'link': 'http://cafe.naver.com/suhui/24298377',
#   'description': '평내동에서 사물함 이용할수 있고 시설 괜찮은 <b>스터디카페</b> 추천좀요! 호평쪽에 있는건 한번 가봤는데 멀어서.... 이제 곧 겨울이니까 도보 15분 사이 내면 좋을것 같아요 그리고 사물함가능한데 조용하고 와이파이... ',
#   'cafename': '수만휘-수능날만점시험지를휘날리자★...',
#   'cafeurl': 'https://cafe.naver.com/suhui'},
#  {'title': '창플에서 <b>스터디카페</b> 브랜딩 디자인시공을 맡아서 오픈 할 첫 작업이 시작되었습니다',
#   'link': 'http://cafe.naver.com/cjdckddus/16498',
#   'description': '창플에서 <b>스터디카페</b> 브랜딩 디자인시공을 맡아서 오픈 할 첫 작업이 시작되었습니다 창플<b>스터디카페</b> 1호점이 되는거죠 창원에 점포계약을 마치고 철거중인 100평매장이 다음주에 착공합니다 윤팀장과 함께 파리공방에... ',
#   'cafename': '창플[창업을 꿈꾸는 사람들의 플랫폼]...',
#   'cafeurl': 'https://cafe.naver.com/cjdckddus'},
#  {'title': '반석역 근처 <b>스터디카페</b> 후기',
#   'link': 'http://cafe.naver.com/djnoen/955794',
#   'description': '상호명 뒤 <b>스터디카페</b>는 생략합니다. 1) *심 - 인테리어 : 가구들이 전부 어두운 색이라서 차분한 분위기이고 의자 시디즈.(요즘은 어디나 시디즈 의자는 기본이예요) - 규모 및 구조 : 이 근처에서는 가장 큽니다. 개방감이... ',
#   'cafename': '대전 노은맘들의 수다방',
#   'cafeurl': 'https://cafe.naver.com/djnoen'},
#  {'title': '<b>스터디카페</b> 오픈 준비중이예요~ (공기청정기 추천해주세요^^)',
#   'link': 'http://cafe.naver.com/mjann/2795383',
#   'description': '네오큐어 공기청정기를 구매하면 미니 공기청정기를 무료로 주길래 여러대를 구입해서 미니는 <b>스터디</b>룸과 <b>카페</b>에 놓으면 좋겠어요. 디자인도 심플하게 인테리어를 해치지 않더라구요. 네오큐어 공기청정기 아시는 분... ',
#   'cafename': '"예쁜카페 예카" 예쁜그릇과앤틱로모노...',
#   'cafeurl': 'https://cafe.naver.com/mjann'},
#  {'title': '<b>스터디카페</b>책상 구경하고 가세요',
#   'link': 'http://cafe.naver.com/0404ab/1902885',
#   'description': '원목과 멜라민 소재를 이용한 <b>스터디카페</b>책상입니다 모두 주문제작한 <b>스터디카페</b>책상 으로 발주후 최대보름정도 걸려요. <b>스터디카페</b>책상은 점주님의 성향에따라 여러가지방법으로 재작되어짐니다. 경기도 용인에... ',
#   'cafename': '인기통(인테리어,리모델링)목수,도배,...',
#   'cafeurl': 'https://cafe.naver.com/0404ab'},
#  {'title': '바로<b>스터디카페</b>',
#   'link': 'http://cafe.naver.com/polstudy/2876471',
#   'description': '공부하지만 남들 보다 좀 더 공부하려고 두시간 더 할예정입니다. 같이 하는게 맞으면 부족한 과목 스터디도 하고 서로 선의 경쟁도 하면서 공부 하실분 찾아요! 술,밥 목적 노노 입니다... 장소는 바로 <b>스터디카페</b>입니당!',
#   'cafename': '경꿈사★경찰공무원을 꿈꾸는 사람들/...',
#   'cafeurl': 'https://cafe.naver.com/polstudy'},
#  {'title': '<b>스터디카페</b> 많이 위험할까요..?',
#   'link': 'http://cafe.naver.com/suhui/24054598',
#   'description': '다들 <b>스터디 카페</b> 가시나요?? 부모님이 위험하대서 집에서 공부하고 있는데 아버지 빼고 가족 셋이 집에 다 있고 게다가 하나는 10살 아래 동생인데 요새 피아노를 배우더니 ㅠㅠ 틈만 나면 피아노 치고 그런 와중에... ',
#   'cafename': '수만휘-수능날만점시험지를휘날리자★...',
#   'cafeurl': 'https://cafe.naver.com/suhui'},
#  {'title': '강일도에 <b>스터디카페</b> 추천요',
#   'link': 'http://cafe.naver.com/everyhomework/731122',
#   'description': '강일도에 <b>스터디카페</b> 추천요',
#   'cafename': '송강맘♥송파맘 강동맘 육아맘카페-송...',
#   'cafeurl': 'https://cafe.naver.com/everyhomework'},
#  {'title': '독서실 vs <b>스터디카페</b>',
#   'link': 'http://cafe.naver.com/tocop/809384',
#   'description': '독서실은 일단위이고 <b>스터디 카페</b>는 시간단위로 하는데 저는 <b>스터디카페</b>가 저에게 맞는것 같네요... ■ 20만 경시생들의 인기글 모음 ■ 경찰최종합격자들의 체력관리법 비밀공개 ㄴ https... ',
#   'cafename': '경수모★경찰공무원 시험/과목/가산점...',
#   'cafeurl': 'https://cafe.naver.com/tocop'},
#  {'title': '경남 진주터미널근처에 <b>스터디카페</b>',
#   'link': 'http://cafe.naver.com/landpro/1535294',
#   'description': '진주터미널이나 경남과기대근처에 조용하고 편안하게 <b>스터디</b>하기 좋은 <b>카페</b> 추천 부탁드립니다..ㅠㅠㅜ 어지간하면 공부할때 집중잘되는데 요즘 갈만한곳이 없네요 겨우 마음에 드는 일반 <b>카페</b>가 하나... ',
#   'cafename': '공사모 ★공인중개사를 사랑하는 모임...',
#   'cafeurl': 'https://cafe.naver.com/landpro'},
#  {'title': '<b>스터디카페</b> 창업비용 관련',
#   'link': 'http://cafe.naver.com/jihosoccer123/602210',
#   'description': '<b>스터디</b>룸 창업 비용 관련하여 알아보고 있는데 기본적으로 어느정도 들어갈까요? 보증금 월세 인건비 전기세 등 외에 들어가는게 있나요? 잇다면 보통 얼마나 들어갈까요?',
#   'cafename': '아프니까 사장이다 [소상공인·자영업...',
#   'cafeurl': 'https://cafe.naver.com/jihosoccer123'},
#  {'title': '프리미엄독서실 운영중인 건물에 <b>스터디카페</b>',
#   'link': 'http://cafe.naver.com/jihosoccer123/531959',
#   'description': '경기도 신도시에서 프리미엄독서실을 운영중인데요, 오픈한지는 3년 조금 넘었구요, 혹시 같은건물 다른층에 <b>스터디카페</b>를 차리면 어떨지 고민중이어서 경험있는 선배님들 의견을 들어보고 싶습니다. 두가지 다 동시에... ',
#   'cafename': '아프니까 사장이다 [소상공인·자영업...',
#   'cafeurl': 'https://cafe.naver.com/jihosoccer123'},
#  {'title': '내년 하반기(10월이후~)쯤에 <b>스터디카페</b> 차리기엔 넘 늦는건가요??',
#   'link': 'http://cafe.naver.com/jihosoccer123/578155',
#   'description': '꾸준히 <b>스터디카페</b>에 대해 찾아보고 알아본 후 내린 결정입니다. 쉬운 길이 어디 있겠습니까? 사업 한다하면 어느누가 하라하겠습니까? 할라고요ㅋㅋ 현재 <b>스터디카페</b>가 포화상태인데 내년10월쯤에 하기에는 넘 늦는건... ',
#   'cafename': '아프니까 사장이다 [소상공인·자영업...',
#   'cafeurl': 'https://cafe.naver.com/jihosoccer123'},
#  {'title': '상남동 화이트펜슬 <b>스터디카페</b> 양도',
#   'link': 'http://cafe.naver.com/joonggonara/794832541',
#   'description': '개인거래(판매), 판매완료, 가격 60,000원, 직접결제(네이버페이 송금), 상남동 화이트펜슬 <b>스터디카페</b> 양도, 상남동 화이트펜슬 <b>스터디카페</b> 양도해요 2주권 양도합니다 급한일있어서 어쩔수 없이 양도하네요',
#   'cafename': '중고나라',
#   'cafeurl': 'https://cafe.naver.com/joonggonara'},
#  {'title': '<b>스터디카페</b> 총무(매일 공부하시는 분)',
#   'link': 'http://cafe.naver.com/dongtanmom/5087081',
#   'description': '매일 <b>스터디카페</b>에서 공부하면서 일하실분 능동 동네<b>스터디카페</b>로 도보 출퇴근 가능하신분 환영합니다. 문자문의: ***-****-****',
#   'cafename': '◆동탄맘들 모여라',
#   'cafeurl': 'https://cafe.naver.com/dongtanmom'},
#  {'title': '나다움SN교육컨설팅&amp;SA<b>스터디카페</b> 모집안내',
#   'link': 'http://cafe.naver.com/lovesiheunggunja/215460',
#   'description': '‘나다움SN교육컨설팅&amp;SA<b>스터디카페</b>(가칭)’ 입니다. 학생들의 코칭과 컨설팅에 많은 문의가 있었으나 여러 상황으로 함께 하지 못했습니다. 그 동안 많은 준비를 해왔고, 2020년 12월 1일 ‘나다움SN교육컨설팅... ',
#   'cafename': '시흥 배곧신도시 총연합회',
#   'cafeurl': 'https://cafe.naver.com/lovesiheunggunja'},
#  {'title': '7회 손해평가사 2차 준비생 <b>스터디</b> 모집 ( 평촌, 안양, 산본, 수원)',
#   'link': 'http://cafe.naver.com/sonpyoung/27345',
#   'description': '3.스터디 지역 평촌 학원가에 <b>스터디 카페</b>가 많으로 평촌 학원가에서 하고자 하며 모인분들과 의논하여 장소를 정하도록 하겠습니다. 4.스터디의 내용 스터디를 한다고 대단한 학문 공부가 아닌 업방위주의 공부이며... ',
#   'cafename': '손해평가사를 사랑하는 모임(손사모)',
#   'cafeurl': 'https://cafe.naver.com/sonpyoung'},
#  {'title': '단구동 <b>스터디카페</b> 추천해주세요',
#   'link': 'http://cafe.naver.com/mapacademy/559443',
#   'description': 'ㅋㄹㄴ때문에 집에서 공부하고 있는데 도저히 공부가 안되서요 <b>스터디카페</b>를 한번 가볼까하는데 혹시 단구동에 관리 잘되고 좀 깨끗한 <b>스터디카페</b> 없을까요?? 괜찮으면 계속 다닐생각인데 진짜 괜찮은곳으로 추천 좀... ',
#   'cafename': '★[하우투] 대한민국 1등 학원,인강,교...',
#   'cafeurl': 'https://cafe.naver.com/mapacademy'},
#  {'title': '대전에<b>스터디카페</b> 추천좀',
#   'link': 'http://cafe.naver.com/emsibt/606821',
#   'description': '집에서만 공부 하는데 너무 답답해서요 <b>스터디카페</b>에서 한번 해보려고하는ㄷㅔ 대전 서구 월평동근처에 <b>스터디카페</b> 추천좀해주세용 ★코로나로 인한 공인중개사시험 주의사항!★ ☞ https://bit.... ',
#   'cafename': '공도사★공인중개사시험일정,무료인강...',
#   'cafeurl': 'https://cafe.naver.com/emsibt'},
#  {'title': '<b>스터디카페</b> 시간권',
#   'link': 'http://cafe.naver.com/kdnstorys/450771',
#   'description': '수유역근처 <b>스터디카페</b> 시간권 30시간 싸게 팝니다. 관심 있으시면 쳇 주세요 [벼룩]상품판매는 일2회만 가능합니다~ 상품이 많을시 한곳에 몰아주세요. 서로간의 기본메너를 지켜주시면, 더욱 기분좋은... ',
#   'cafename': '카페 강봉원 :: 강북구 도봉구 노원구...',
#   'cafeurl': 'https://cafe.naver.com/kdnstorys'},
#  {'title': '분위기 괜찮은 <b>스터디카페</b> 알려주세요',
#   'link': 'http://cafe.naver.com/koreakmc/268233',
#   'description': '독서실은 너무 분위기가 답답하다고 해서 <b>스터디카페</b> 괜찮은곳있으면 거기로 가고싶다고 하네요 요즘 고3이라 공부한다고 바쁜데 뭐든 원하는거있음 알아봐주는중이라 <b>스터디카페</b> 좀 알려주세요',
#   'cafename': '송파♡강동맘 톡 - 송파맘카페, 강동맘...',
#   'cafeurl': 'https://cafe.naver.com/koreakmc'},
#  {'title': '대학교 앞 무인<b>스터디 카페</b>?',
#   'link': 'http://cafe.naver.com/billiardsforus/3711',
#   'description': '요즘 <b>스터디 카페</b>가 너무 많이 생긴거 같아서 창업하는데 고민이 많습니다. 대학교 앞에 무인 <b>스터디 카페</b>는 앞으로 괜찮을까요? 고민입니다',
#   'cafename': '우동독 -우리동네독서실(독서실,스터디...',
#   'cafeurl': 'https://cafe.naver.com/billiardsforus'},
#  {'title': '<b>스터디카페</b> 창업준비하고 있습니다',
#   'link': 'http://cafe.naver.com/billiardsforus/3576',
#   'description': '안녕하세요, <b>스터디카페</b> 창업에 관심있는 1인입니다. 집이 신도림동이라 여기서 출퇴근하기 멀지 않은 지역에 <b>스터디 카페</b> 창업하려고 알아보고 있는데, 입지를 잡는 것이 생각보다 녹록치 않네요. <b>스터디카페</b> 매매정보... ',
#   'cafename': '우동독 -우리동네독서실(독서실,스터디...',
#   'cafeurl': 'https://cafe.naver.com/billiardsforus'},
#  {'title': '(일산) 가치투자 <b>스터디</b> 맴버 모집합니다',
#   'link': 'http://cafe.naver.com/vilab/168090',
#   'description': '- 인원 : 10명 - 스터디 시간 : 매달 첫번째 토요일 오전 10 ~ 12시 - 스터디 장소 : 마두역 5번 출구, 301 <b>스터디 카페</b> - 스터디 운영 : 투자 공유 - 회비 : 4천원(<b>스터디 카페</b> 대여료) - 카페에 가입하여 눈팅만 하다가... 몇 꼭지... ',
#   'cafename': '가치투자연구소',
#   'cafeurl': 'https://cafe.naver.com/vilab'},
#  {'title': '인천 괜찮은 <b>스터디카페</b>',
#   'link': 'http://cafe.naver.com/kts9719/1844463',
#   'description': '집에 있으니 정말 공부가 안될 거 같아서 나와서 하려고 하는데 인천에 괜찮은 <b>스터디카페</b> 있을까요? ★이번주 공시생 1만명 이상이 본 글★ [단독] 공무원 2021 시험 개편/예고... ',
#   'cafename': '닥공사★9급공무원,7급공무원,경찰,소...',
#   'cafeurl': 'https://cafe.naver.com/kts9719'},
#  {'title': '<b>스터디카페</b> 사장님들 질문있습니다.~',
#   'link': 'http://cafe.naver.com/jihosoccer123/541346',
#   'description': '<b>스터디카페</b> 창업 준비 중이에요~ 68평 정도되는데 학구열이 엄청난 지역은아니라서, 카페느낌으로 스터디룸 없이 준비중인데요 스터디존1,2 나누고 카페존하나 넣어서 카페에서 취식가능하게 하려고하거든요~ 대신... ',
#   'cafename': '아프니까 사장이다 [소상공인·자영업...',
#   'cafeurl': 'https://cafe.naver.com/jihosoccer123'},
#  {'title': '<b>스터디카페</b> 운영하신분 계실까요',
#   'link': 'http://cafe.naver.com/anycard/938867',
#   'description': '<b>스터디카페</b> 사업자등록시 업종이 어떻게되나요? 업태와 종목알려주시면 너무너무 감사드리겠습니다',
#   'cafename': '신용카드 박물관',
#   'cafeurl': 'https://cafe.naver.com/anycard'},
#  {'title': '<b>스터디카페</b>?초4데꼬갈만한곳인가요.?',
#   'link': 'http://cafe.naver.com/mathall/1968583',
#   'description': '<b>스터디카페</b>?데려가서 공부시켜볼까하는데.. 저도 한번도 가본적이없어서요 학원을 안다니니 세상 혼자 공부하는 아이인줄알거든요.. 여기가 또..완전 시골지역이다보니..자기가 젤 한다 생각두 하구요..ㅜㅜ 그래서 주말에... ',
#   'cafename': '[상위1%카페] 대한민국 상위1% 교육정...',
#   'cafeurl': 'https://cafe.naver.com/mathall'},
#  {'title': '소하동 플랜24 <b>스터디카페</b> 정기권 양도합니다~',
#   'link': 'http://cafe.naver.com/joonggonara/795519953',
#   'description': '개인거래(판매), 판매중, 가격 80,000원, 직접결제, 소하동 플랜24 <b>스터디카페</b> 정기권 양도합니다~, 우리동네 게시글 작성 시 말머리 설정은 필수입니다. 28일 11만원에 결제 했습니다~ 현재 24일 남아있어요! 독서실을... ',
#   'cafename': '중고나라',
#   'cafeurl': 'https://cafe.naver.com/joonggonara'},
#  {'title': '비에이블<b>스터디카페</b> 관악성현센터 시간권 양도합니다.',
#   'link': 'http://cafe.naver.com/joonggonara/795427299',
#   'description': '개인거래(판매), 판매중, 가격 60,000원, 직접결제, 비에이블<b>스터디카페</b> 관악성현센터 시간권 양도합니다., 우리동네 게시글 작성 시 말머리 설정은 필수입니다. 현대시장 근처 비에이블<b>스터디카페</b>(관악성현센터) 시간권... ',
#   'cafename': '중고나라',
#   'cafeurl': 'https://cafe.naver.com/joonggonara'},
#  {'title': '<b>스터디 카페</b>랑 일반 카페 중에,,',
#   'link': 'http://cafe.naver.com/askjeon/79585',
#   'description': '<b>스터디 카페</b>가 더 잘 되긴 하는데 뭔가 막 필기 공부를 한다던가 그런 게 아닐 땐 일반 카페 가는 게 더 좋은 거 같아요,, 특히 자소서 쓸 때! 커피도 마실 수 있으니까여 ㅎㅎㅎ --------------------------------- 화이팅, 취뽀, 힘내요... ',
#   'cafename': '전수환★공기업,공공기관취업,경영학,...',
#   'cafeurl': 'https://cafe.naver.com/askjeon'},
#  {'title': '무인<b>스터디카페</b> 있을까요?',
#   'link': 'http://cafe.naver.com/baby8/2048109',
#   'description': '안녕하세요. 아이들 교육때문에 무인<b>스터디카페</b> 알아보고있습니다.지금은 인천 부평 살고있는데 9월쯤 시흥 배곧동으로 이사갑니다. ㅎㅎ 괜찮은 무인시스템으로 운영되는 <b>스터디카페</b> 있을까요?',
#   'cafename': '인천맘 소중한인연 (인천맘 대표카페,...',
#   'cafeurl': 'https://cafe.naver.com/baby8'},
#  {'title': '<b>스터디카페</b> 추천좀요~~',
#   'link': 'http://cafe.naver.com/minraknewcity/151531',
#   'description': '<b>스터디카페</b> 이용하신분중에 편리하고 쾌적한곳 추천부탁드립니다. 성인이 이용할려구요~~ㅎ 이왕이면 주차공간 여유있는곳이면 더 좋을것같네요~~^^',
#   'cafename': '의정부 민락신도시카페 (민락1지구,민...',
#   'cafeurl': 'https://cafe.naver.com/minraknewcity'},
#  {'title': '창원 서상동이나 중동에 <b>스터디카페</b> 추천',
#   'link': 'http://cafe.naver.com/mapacademy/560025',
#   'description': '서상동이나, 중동 근처로 괜찮은 <b>스터디카페</b> 아시는 분 추천 좀 해주세요^^;; 공부하러 가는 거니까 어느 정도는 조용했으면 하는데 부담스러울 정도로 조용하거나 폐쇄된 느낌이드는 곳은 정중히 사양하구요...ㅎ 시설을... ',
#   'cafename': '★[하우투] 대한민국 1등 학원,인강,교...',
#   'cafeurl': 'https://cafe.naver.com/mapacademy'},
#  {'title': '<b>스터디카페</b> 어떰 ?.?',
#   'link': 'http://cafe.naver.com/lolkor/25540428',
#   'description': '여태 쭉 독서실만 댕겻었는데 <b>스터디카페</b>로 옮길까 고민중 독서실이랑비슷ㅅ함?',
#   'cafename': '리그오브레전드 한국커뮤니티 - LoLKo...',
#   'cafeurl': 'https://cafe.naver.com/lolkor'},
#  {'title': '#마포#독서실&amp;<b>스터디카페</b>',
#   'link': 'http://cafe.naver.com/mapomommy/896219',
#   'description': '제로스페이스 <b>스터디카페</b>를 소개합니다. ^^ 다른 곳에서 경험할 수 없는 쾌적하고 조용한 학습공간을 체험해보세요~~ 1. 다양한 좌석유형 독서실&amp;카페형의 오픈형, 반밀폐형의 입식/좌식형 좌석 2. 전좌석 1200mm의... ',
#   'cafename': '마이키_마포에서 아이 키우기',
#   'cafeurl': 'https://cafe.naver.com/mapomommy'},
#  {'title': '[자료] <b>스터디카페</b> 프랜차이즈 브랜드별 매출현황 - 공정위 2018',
#   'link': 'http://cafe.naver.com/jihosoccer123/469851',
#   'description': '<b>스터디카페</b> 브랜드별 평균매출표입니다. 출처 공정거래위. 2018년말까지 기준, 자료는 2020.5월 현재. https://franchise.ftc.go.kr/user/extra/main/70/firHope/listBrand/jsp/LayOutPage.do 낼모레 모임에 안주꺼리 겸해서...... ',
#   'cafename': '아프니까 사장이다 [소상공인·자영업...',
#   'cafeurl': 'https://cafe.naver.com/jihosoccer123'},
#  {'title': '어양동<b>스터디카페</b> 괜찮은 곳 있을까요?',
#   'link': 'http://cafe.naver.com/miznett/2300805',
#   'description': '어양동<b>스터디카페</b> 괜찮은 곳 있을까요? 전라북도 익산시 어양동 거주하는데요~ 아이들 요새 <b>스터디카페</b> 보내려고 이곳저곳 알아보고있어요~ 괜찮은 어양동<b>스터디카페</b> 있으면 추천해주세요!',
#   'cafename': '미즈넷-임신 육아 임산부 교육 핫딜 아...',
#   'cafeurl': 'https://cafe.naver.com/miznett'},
#  {'title': '전주에 <b>스터디카페</b> 추천해주세요~',
#   'link': 'http://cafe.naver.com/m2school/2802713',
#   'description': '<b>스터디카페</b> 어디가 좋은가요? ● 지방직공무원 7급 경쟁률 [확인] ㄴhttps://bit.ly/3heuz1w ● ★피티윤T★공무원 면접 비밀자료 놓치면 후회합니다! ㄴhttps://bit.ly/2E5S2Ua ● 2020 군무원... ',
#   'cafename': '독공사★9급공무원,7급공무원,소방,군...',
#   'cafeurl': 'https://cafe.naver.com/m2school'},
#  {'title': '<b>스터디카페</b> 다니시는 분들 계신가요?',
#   'link': 'http://cafe.naver.com/landpro/1530744',
#   'description': '요즘 <b>스터디카페</b> 좀 어떤가요 ㅠㅠ? 사람들 많나요? ※ 연예인도 공인중개사를 준비한다고? 배우 최정윤의 공중사 도전기 &gt; https://bit.ly/2DWp6xZ ※ 부동산 최강 5인과 개그맨 홍록기의 만남! 부동산... ',
#   'cafename': '공사모 ★공인중개사를 사랑하는 모임...',
#   'cafeurl': 'https://cafe.naver.com/landpro'},
#  {'title': '상가에 <b>스터디카페</b> 생겼나요??',
#   'link': 'http://cafe.naver.com/parkxii/23613',
#   'description': '차타고 지나가다가 언뜻 <b>스터디카페</b>인지 독서실인지 오픈한다고 본거같은데 생긴건가용??',
#   'cafename': '청주리버파크자이 입주자 카페',
#   'cafeurl': 'https://cafe.naver.com/parkxii'},
#  {'title': '<b>스터디카페</b>가 뭔가요?',
#   'link': 'http://cafe.naver.com/baby8/2055308',
#   'description': '보니까 선배 언니들도 그렇고 시험기간이면 독서실 안가고 <b>스터디 카페</b>를 간다고 하는데 흔히 알고 있는 독서실이랑 <b>스터디 카페</b>랑 차이가 뭔지 알수있을까요? ㅠ,,ㅠ 딸아이도 가고싶어하는 눈치인데 지금은 시국도... ',
#   'cafename': '인천맘 소중한인연 (인천맘 대표카페,...',
#   'cafeurl': 'https://cafe.naver.com/baby8'},
#  {'title': '동네 <b>스터디카페</b> 갈 수 있나요?',
#   'link': 'http://cafe.naver.com/twozone/296886',
#   'description': '<b>스터디카페</b> 영업유무 아시는분~~',
#   'cafename': '인천 서창맘들의 공간♡',
#   'cafeurl': 'https://cafe.naver.com/twozone'},
#  {'title': '부산 독서실이나 <b>스터디카페</b> 추천이요ㅠㅠ',
#   'link': 'http://cafe.naver.com/m2school/2796000',
#   'description': '<b>스터디카페</b> 다니는데 독서실로 옮길까 고민중이에요ㅠㅠ 다들 주로 어디서 공부하셨나요!? 집공은 안되겠죠 ㅎㅎㅎ ● 공무원 9급 VS 공무원 7급 고민되나요? ㄴhttps://bit.ly/33OJNq0 ● 지방직... ',
#   'cafename': '독공사★9급공무원,7급공무원,소방,군...',
#   'cafeurl': 'https://cafe.naver.com/m2school'},
#  {'title': '롯데시네마 근처 <b>스터디카페</b>',
#   'link': 'http://cafe.naver.com/seosanmom/874495',
#   'description': '<b>스터디 카페</b> 생겼던데 오픈한건가요? 오픈 아직이라면 언제 하는지 아시는 분 알려주세여~ 댓글 미리 감사합니다^^',
#   'cafename': '★서산 엄마들의 모임★',
#   'cafeurl': 'https://cafe.naver.com/seosanmom'},
#  {'title': '<b>스터디카페</b>',
#   'link': 'http://cafe.naver.com/kts9719/1623120',
#   'description': '늦은 나이에 맘먹고 공부시작하려고 <b>스터디카페</b> 가봤는데 확실히COVID19전과는 사람이 많이 없네요. 아이 <b>스터디 카페</b> 상담받으러 온줄알고 사장님이 친절히 상담해줘서 듣고왔습니다. ▲ 글 쓸 때 위의 안내사항... ',
#   'cafename': '닥공사★9급공무원,7급공무원,경찰,소...',
#   'cafeurl': 'https://cafe.naver.com/kts9719'},
#  {'title': '동네 <b>스터디카페</b> 문열었나요?',
#   'link': 'http://cafe.naver.com/samwonmoms/740920',
#   'description': '내일 공부해야하는데 도서관은 아직 휴관이더라구요 삼송.원흥에 <b>스터디카페</b> 몇 군데있던데 재오픈했나요?',
#   'cafename': '삼송 원흥 지축 향동 덕은 엄마들 모여...',
#   'cafeurl': 'https://cafe.naver.com/samwonmoms'},
#  {'title': '<b>스터디카페</b> 싸움도 생기고 난리네요',
#   'link': 'http://cafe.naver.com/kts9719/1459314',
#   'description': '<b>스터디카페</b> 안에서 기침으로 인해서 싸움 났는데경찰까지 올정도로 싸움났다네요<b>스터디카페</b>에서 당연히 마스크는 써야하는게맞지만 저정도로 싸움이...ㅁㅊ.. 코로나때문에 진짜 공부하는사람들도 살벌한... ',
#   'cafename': '닥공사★9급공무원,7급공무원,경찰,소...',
#   'cafeurl': 'https://cafe.naver.com/kts9719'},
#  {'title': '<b>스터디 카페</b> 인테리어 시작~~',
#   'link': 'http://cafe.naver.com/jihosoccer123/510912',
#   'description': '<b>스터디 카페</b> 공사 시작합니다 처음 스카를 하기로 마음먹고 바로 상가보고 6월초 계약. 이제 인테리어만 하면되겠네하고 마음편하게 생각했지만...ㅠㅠ 험난했던 한달간 저의 준비과정을 소개하려합니다.... ',
#   'cafename': '아프니까 사장이다 [소상공인·자영업...',
#   'cafeurl': 'https://cafe.naver.com/jihosoccer123'},
#  {'title': '스터디 대여공간 찾고있어요 <b>스터디카페</b> 단체석 있는 곳이나 추천좀 해주세요.',
#   'link': 'http://cafe.naver.com/hee11974/688893',
#   'description': '본사에서 스터디랑 회의를 지역별 온라인으로 진행한다면서.<b>스터디카페</b> 단체석이나 스터디 가능한 대여공간을 찾으라고 하는데 혹시 추천해 주실 수 있나요? 빔프로젝트는 그냥 7명이 모두 노트북 켜놓고 하면... ',
#   'cafename': '♬~광교맘 모여라',
#   'cafeurl': 'https://cafe.naver.com/hee11974'},
#  {'title': '집공이 안되어서 <b>스터디카페</b> 월정액 구입했네요..',
#   'link': 'http://cafe.naver.com/kts9719/1942758',
#   'description': '오늘 <b>스터디카페</b> 가서 월정액 구입하고 왔습니다.. 굴포천역 쪽에 보니까 <b>스터디카페</b> 독서실 많아서 그중에 르하임 스카로 결정을 하였습니다.. 앞으로 평일엔 퇴근하고 가서 공부하고... ',
#   'cafename': '닥공사★9급공무원,7급공무원,경찰,소...',
#   'cafeurl': 'https://cafe.naver.com/kts9719'},
#  {'title': '저도 드디어 <b>스터디</b> 퍼밋 받았습니다',
#   'link': 'http://cafe.naver.com/iliveincan/118327',
#   'description': '이틀전 <b>스터디 카페</b>에서 열심히 과제 중이었는데 유학원에서 부재중 전화가 한통 와 있더라구요. 대개는 전화를 받으면 그리 좋은 소식이 아니었던지라 반신반의하며 다시 전화를 걸었는데 아니!!!! 드디어 스터디 퍼밋이... ',
#   'cafename': '캐나다를 사랑하는 사람들',
#   'cafeurl': 'https://cafe.naver.com/iliveincan'},
#  {'title': '수원 권선동 <b>스터디 카페</b>에서 함께 공부하실분 있나요?',
#   'link': 'http://cafe.naver.com/prepharm/147996',
#   'description': '권선동소재 평생교육학습관 근처 <b>스터디카페</b>를 정하고 내년 시험날까지 함께 다니실분(평생교육학습관 풀리면 같이 옮기실 분) -아침에 간단한 인사로 출석체크 -점심식사 이렇게 하려합니다~ 관심 있으신분 쪽지... ',
#   'cafename': '약대가자!!!',
#   'cafeurl': 'https://cafe.naver.com/prepharm'},
#  {'title': '<b>스터디카페</b> 창업 어떻게 생각하세요?',
#   'link': 'http://cafe.naver.com/jinheemom/2256370',
#   'description': '신랑이 자격증공부중으로 <b>스터디카페</b> 다니면서 공부중인데 우리동에는 없어서 옆동네이 다니고 있어요 차로 5~10분거리 하지만 저희동네는 상권은 크게 발달은 안되어있지만 초중고등학교 도보내로 하나씩 있어요... ',
#   'cafename': '★★★ 진희맘 홀릭 ★★★ 육아 및 해...',
#   'cafeurl': 'https://cafe.naver.com/jinheemom'},
#  {'title': '[사당] 한전KPS 면접<b>스터디</b> 구합니다',
#   'link': 'http://cafe.naver.com/uccplus/1498175',
#   'description': '장소: 사당역 <b>스터디카페</b>(미리 예약후 진행) 인원: 최소 4명 함께 회사 분석하고 면접 예상 질문 주고받으며 열심히 면접 스터디 참여하실 분들 환영합니다. 처음으로 직접 만들어보는 스터디인 만큼 다함께 잘... ',
#   'cafename': '공취사│공기업,공공기관,공무원,민경...',
#   'cafeurl': 'https://cafe.naver.com/uccplus'},
#  {'title': '스토피아 <b>스터디카페</b> 월곡점 80시간양도합니다',
#   'link': 'http://cafe.naver.com/joonggonara/793603998',
#   'description': '개인거래(판매), 판매중, 가격 80,000원, 직접결제, 스토피아 <b>스터디카페</b> 월곡점 80시간양도합니다, 우리동네 게시글 작성 시 말머리 설정은 필수입니다. 80시간 8만원에판매합니다 기간제한 X 연락주세요',
#   'cafename': '중고나라',
#   'cafeurl': 'https://cafe.naver.com/joonggonara'},
#  {'title': '후곡 근처에 <b>스터디카페</b>있나요?',
#   'link': 'http://cafe.naver.com/isajime/4657544',
#   'description': '후곡 근처에 <b>스터디 카페</b> 좋은 곳이 있나요? ================================ 일산아지매는 배려입니다 당신의 한마디가 카페를 만들어갑니다! ================================',
#   'cafename': '일산아지매',
#   'cafeurl': 'https://cafe.naver.com/isajime'},
#  {'title': '대구님들 동성로반월당쪽 <b>스터디카페</b> 추천좀',
#   'link': 'http://cafe.naver.com/dieselmania/32663940',
#   'description': '반월당이나 동성로 스터디 5-6인룸이나 괜찮은 <b>스터디카페</b>추천좀 해주세요 !!!!',
#   'cafename': '●디젤매니아● 대한민국 일등 패션 커...',
#   'cafeurl': 'https://cafe.naver.com/dieselmania'},
#  {'title': '안산 상록구 <b>스터디카페</b> 어디 괜찮은 곳 있을까요.',
#   'link': 'http://cafe.naver.com/miznett/2283777',
#   'description': '안산 상록구 <b>스터디카페</b> 찾고있는데 어디 괜찮은 곳 없을까요~? 추천좀 부탁드려요!! 독서실에서 <b>스터디카페</b>로 아이들이 옮기고 싶어해서 알아보고있는중이에요~ ^^',
#   'cafename': '미즈넷-임신 육아 임산부 교육 핫딜 아...',
#   'cafeurl': 'https://cafe.naver.com/miznett'},
#  {'title': '면접/인적성<b>스터디</b> 모집합니다 (신촌)',
#   'link': 'http://cafe.naver.com/dokchi/10520193',
#   'description': '[면접 스터디] * 면접스터디 신촌 (월,수 오전 9:00~11:00) -신촌 미플 <b>스터디 카페</b> (때때로 달라질 수 있습니다!:) * 학과: 문과 (금융 +사기업) * 모집인원 (총원 5명) * 진행방식 - 1주차: 기본 질문 30문항... ',
#   'cafename': '독취사-취업,대학생,대기업,공기업,GS...',
#   'cafeurl': 'https://cafe.naver.com/dokchi'},
#  {'title': '<b>스터디카페</b> 어떤가요?',
#   'link': 'http://cafe.naver.com/no1sejong/2618667',
#   'description': '공부할게 있는데.. 집에선 너무 공부가안되서요ㅜ 해야할일만 보이고.. 마스크 필수착용이라고는 하는데 혹시 주변에 <b>스터디카페</b> 가보신분 계신가요?',
#   'cafename': '세종맘카페 세종맘들의 행복한 이야기...',
#   'cafeurl': 'https://cafe.naver.com/no1sejong'},
#  {'title': '용인동백 <b>스터디카페</b> 공간샘 기간권 10일+사물함25일포함.',
#   'link': 'http://cafe.naver.com/joonggonara/796934065',
#   'description': '개인거래(판매), 판매중, 가격 39,000원, 직접결제(네이버페이 송금), 용인동백 <b>스터디카페</b> 공간샘 기간권 10일+사물함25일포함., 2주권(14일에 75000원입니다. 사물함 한달10000원)',
#   'cafename': '중고나라',
#   'cafeurl': 'https://cafe.naver.com/joonggonara'},
#  {'title': '신도시 독서실이나 <b>스터디카페</b>',
#   'link': 'http://cafe.naver.com/doorkong/2728806',
#   'description': '신도시에 독서실이나 <b>스터디카페</b> 괜찮은곳추천좀 부탁드립니다 중딩인데 <b>스터디카페</b> 끊어달라해서요 마음변하기전에 끊어주려고요',
#   'cafename': '안산 시흥 맘 모여라',
#   'cafeurl': 'https://cafe.naver.com/doorkong'},
#  {'title': '창원 반송동 <b>스터디카페</b> 추천좀 해주세요~',
#   'link': 'http://cafe.naver.com/baby8/2033844',
#   'description': '창원 반송동 <b>스터디카페</b> 추천좀 부탁드려요~아이가 창원 반송동에서 자취하고 있는데, 막상 찾아보니 딱 맘에드는 곳이 없기도 하고, 그래서 추천좀 받아보려해요~창원 반송동 <b>스터디카페</b> 어디 괜찮은 곳 있을까요~?',
#   'cafename': '인천맘 소중한인연 (인천맘 대표카페,...',
#   'cafeurl': 'https://cafe.naver.com/baby8'},
#  {'title': '르하임 <b>스터디카페</b> 서울대점 220시간 양도',
#   'link': 'http://cafe.naver.com/joonggonara/789787641',
#   'description': '개인거래(판매), 판매중, 가격 170,000원, 직접결제(네이버페이 송금), 르하임 <b>스터디카페</b> 서울대점 220시간 양도, 우리동네 게시글 작성 시 말머리 설정은 필수입니다. 서울대입구역 8번출구에 있는 르하임 <b>스터디카페</b>... ',
#   'cafename': '중고나라',
#   'cafeurl': 'https://cafe.naver.com/joonggonara'},
#  {'title': '<b>스터디카페</b>는 ㄹㅇ 갈수록 좋아진다',
#   'link': 'http://cafe.naver.com/lolkor/25122815',
#   'description': '또 새로 생겨서 지금 도보 10분거리에 <b>스터디카페</b> 8갠데 2층다락방까지 생김ㄷㄷ 독서실합치면 20개는 되는데 독서실이 망할듯',
#   'cafename': '리그오브레전드 한국커뮤니티 - LoLKo...',
#   'cafeurl': 'https://cafe.naver.com/lolkor'},
#  {'title': '<b>스터디카페</b> 공용물건..',
#   'link': 'http://cafe.naver.com/remonterrace/26897368',
#   'description': '참 이기적이지않나요?ㅜ 전에 직장근처 <b>스터디카페</b> 다닐때도 사장님이 휴게실에 간식거리 둔거 누가 박스채 들고갔다고 cctv찍혔으니 범인은 소명하라고 했었는데ㅋㅋㅋ 아 진짜ㅡ... 스탠드 짜증나서 포스트잍에 써서... ',
#   'cafename': '레몬테라스 [인테리어,리폼,DIY,요리,...',
#   'cafeurl': 'https://cafe.naver.com/remonterrace'},
#  {'title': '<b>스터디카페</b> 창업준비중인데 조언좀부탁드려요',
#   'link': 'http://cafe.naver.com/jihosoccer123/465706',
#   'description': '일전에 42평 <b>스터디 카페</b> 작은가요? 라고 글을 올렸던 창업고민중인 초초보 입니다 너무나 많은 분들이 조언을 주셔서 너무 감사합니다 그런데 많은 분들이 평수가 작다고 하셔서 고민중이네요 그래서 염치불구하고... ',
#   'cafename': '아프니까 사장이다 [소상공인·자영업...',
#   'cafeurl': 'https://cafe.naver.com/jihosoccer123'},
#  {'title': '중학생도 <b>스터디 카페</b> 가나요?',
#   'link': 'http://cafe.naver.com/mathall/1950552',
#   'description': '아직은 이른 것 같지만 집도 덥고 집중도 잘 안되는 것 같아서요. 중학생들도 <b>스터디카페</b> 보내시나요? 만약 간다면 선택기준은 무엇인가요? 핸드폰 관리는 되는지 궁금합니다.',
#   'cafename': '[상위1%카페] 대한민국 상위1% 교육정...',
#   'cafeurl': 'https://cafe.naver.com/mathall'},
#  {'title': '당진<b>스터디 카페</b>',
#   'link': 'http://cafe.naver.com/dj114/370980',
#   'description': '당진 <b>스터디 카페</b> 중에 강성태 그루 <b>스터디카페</b> 있나요?? 신터 근처에서 본거 같은데 인터넷에는 안나오네요',
#   'cafename': '당진 부동산',
#   'cafeurl': 'https://cafe.naver.com/dj114'},
#  {'title': '향남 1지구 yg <b>스터디카페</b>',
#   'link': 'http://cafe.naver.com/hnmom/1286459',
#   'description': '향남 1지구에 yg <b>스터디 카페</b>가 생겼다는 얘길 즐었는데 가보신 분 계시나요?? 여기 카페에서 노트북해도 되는 걸까요? 아직 리뷰만 보고 안 가봐서 ㅠㅠ',
#   'cafename': '향남 대표카페 향남 맘스홀릭 (향남1,...',
#   'cafeurl': 'https://cafe.naver.com/hnmom'},
#  {'title': '<b>스터디 카페</b> 1일 저렴한데 만성 혁신 어디 있을까요?',
#   'link': 'http://cafe.naver.com/aliceland78/139862',
#   'description': '아파트 도서관이 문을 닫아서요 <b>스터디 카페</b> 당일권 저렴한데 공유 점 해주세요 공부 하고 싶은 1인 입니다. 정말 코로나 땜에 너무 힘드네요ㅠㅠ',
#   'cafename': '전주혁신맘 모여라',
#   'cafeurl': 'https://cafe.naver.com/aliceland78'},
#  {'title': '우노스 <b>스터디카페</b> 키오스크 할인 이벤트 !!',
#   'link': 'http://cafe.naver.com/jihosoccer123/515783',
#   'description': "우노스 <b>스터디카페</b> 키오스크 할인이벤트 정책이 출시되어 '아프니까 사장이다' 회원님들에게 가장 먼저 공유드립니다 ! 가격 정책표는 첨부파일에서 확인해주세요 ! 우노스 <b>스터디카페</b>용 키오스크는 21인치형... ",
#   'cafename': '아프니까 사장이다 [소상공인·자영업...',
#   'cafeurl': 'https://cafe.naver.com/jihosoccer123'},
#  {'title': '<b>스터디카페</b> 분위기 어떤가요?',
#   'link': 'http://cafe.naver.com/consumerizm/1622699',
#   'description': '요즘 기사시험 때문에 <b>스터디카페</b> 시간권 구매했는데 퇴근하면 자리도 거의없고 솔직히 대화없는 스벅인 분위기더라구요 우당탕탕이 계속... 다른곳도 이럴까요?',
#   'cafename': 'K R R R',
#   'cafeurl': 'https://cafe.naver.com/consumerizm'},
#  {'title': '요즘엔 비대면 <b>스터디카페</b>가 대세! <b>스터디카페</b> 무인키오스크 임대 렌탈 알아보기',
#   'link': 'http://cafe.naver.com/allprinter/5385',
#   'description': '#<b>스터디카페</b>키오스크렌탈 #키오스크렌탈 #키오스크임대 #키오스크추천 #무인결제기 요즘엔 비대면 <b>스터디카페</b>가 대세! <b>스터디카페</b> 무인키오스크 임대 및 렌탈 인건비는 줄이고 매출은 올릴 수 있는 무인 키오스크!... ',
#   'cafename': '칼라복합기 임대/렌탈 전문 올프린터[...',
#   'cafeurl': 'https://cafe.naver.com/allprinter'},
#  {'title': '<b>스터디카페</b>vsㅇㅇ관리형독서실!!',
#   'link': 'http://cafe.naver.com/hangilhistory/515319',
#   'description': '<b>스터디카페</b>의 3배에 해당하는 돈 주더라도 다닐만한 가치가 있을까요? 이번에 소방 풀어봤는데 국어, 영어 각각 95점 나와서 다른 암기과목 좀만하면 내년 지방직에서 가능성 있겠다 생각해서 딱 1년만 죽어라 할... ',
#   'cafename': '전한길한국사',
#   'cafeurl': 'https://cafe.naver.com/hangilhistory'},
#  {'title': '[서울] 농협은행 논술 5급 <b>스터디</b> 인원 충원합니다!',
#   'link': 'http://cafe.naver.com/nhhnhh/332923',
#   'description': '스터디 일정 : 목(19:00~21:00), 일(매주 변동) 진행 장소: 약수역, 종로 근처 <b>스터디카페</b> 진행 방식 : 1. 매 스터디 약술 2개 논술 2개 주제 정해서 개요 짜오기 2. 서로 개요 짜온거 이야기해보고 피드백 3. 약술 논술... ',
#   'cafename': '농준모 : 농협(은행 중앙회 지역)채용...',
#   'cafeurl': 'https://cafe.naver.com/nhhnhh'},
#  {'title': '<b>스터디카페</b>랑 피씨방 코로나 무법지대네요',
#   'link': 'http://cafe.naver.com/eunpyungmom/425132',
#   'description': '저희 애가 <b>스터디카페</b> 간다길래 당장 환불 받으라고 했어요 제가 먼저 실험차 몇군데 가보니 한공간에 다수가 마스크 안쓰고 있고 간혹 재채기 하는 사람들도 보이더라구요.. 특히 어디서 온지 알 수 없는 사람들이... ',
#   'cafename': '♥은평맘 톡톡♥',
#   'cafeurl': 'https://cafe.naver.com/eunpyungmom'},
#  {'title': '지금 다니는 <b>스터디카페</b>',
#   'link': 'http://cafe.naver.com/suhui/23845565',
#   'description': '저희 지역엔 <b>스터디카페</b>가 집과 20분거리인 한곳밖에 없습니다 학원과 과외하는 곳이랑 전부 1분거리라서 다니고 있는데요 아침에 갈 때, 저녁에 올 때 너무 시간낭비하는 것 같아요 집에서 3분거리인 1인용독서실 하나... ',
#   'cafename': '수만휘-수능날만점시험지를휘날리자★...',
#   'cafeurl': 'https://cafe.naver.com/suhui'},
#  {'title': '<b>스터디 카페</b> 잘아시는 분',
#   'link': 'http://cafe.naver.com/everything1004/127317',
#   'description': '안녕하세요 혹시 계신분들 중 <b>스터디 카페</b> 운영하시는 분 있으신가요? 투잡으로 고민중인데 전망이나 현재 하시는 분들 의견 궁금하네요',
#   'cafename': '대전부동산의 모든것',
#   'cafeurl': 'https://cafe.naver.com/everything1004'},
#  {'title': '자율 <b>스터디</b> 하고 싶은데...',
#   'link': 'http://cafe.naver.com/specup/6517404',
#   'description': '기사 카페를 들어가서 찾기엔 또 너무 협소해져서 쥬륵 취준생들 좀 자격증 공부한다 생각하고 오프라인으로 <b>스터디카페</b>나 일반 카페 가서 좀 공부하고............그런거 하고싶은데 우짜면 좋을까여? 보통 자율... ',
#   'cafename': '스펙업 | 취업,대학생,대외활동,공모전...',
#   'cafeurl': 'https://cafe.naver.com/specup'},
#  {'title': '이제마<b>스터디카페</b> 고척점 기간권 양도합니다 (11월 19일까지 사용 가능)',
#   'link': 'http://cafe.naver.com/joonggonara/788879736',
#   'description': '개인거래(판매), 판매완료, 가격 110,000원, 안전결제, 네이버페이, 이제마<b>스터디카페</b> 고척점 기간권 양도합니다 (11월 19일까지 사용 가능), 이제마 <b>스터디카페</b> 고척점 기간권 양도합니다. 바코드로 출입이 가능한... ',
#   'cafename': '중고나라',
#   'cafeurl': 'https://cafe.naver.com/joonggonara'},
#  {'title': '그루 <b>스터디 카페</b>',
#   'link': 'http://cafe.naver.com/mommytalktalk79/107752',
#   'description': '가끔 <b>스터디카페</b>,독서실 어떤지 물어보는 글들이 있어서 올려보아유 그루<b>스터디 카페</b> 경대연합,베스킨,던킨 건물8층에 있어요 전 어제 하루 8시간 8000원에 결제하고 들어갔어요 독서대도 있더군요 휴게실에는 믹스커피... ',
#   'cafename': '경북도청신도시 마미톡톡(맘카페)',
#   'cafeurl': 'https://cafe.naver.com/mommytalktalk79'},
#  {'title': '면접<b>스터디</b> 충원합니다~',
#   'link': 'http://cafe.naver.com/publiccor/196995',
#   'description': '한분이 다음주 면접이라 이번주까지 하고 빠질 예정입니다. 모집인원은 1-2명 정도 생각합니다! 시간은 7시반~9시반, 장소는 분당 내 <b>스터디카페</b>(정자), 평일 2회~3회 고려중입니다! 관심 있으신분은 쪽지나 댓글 주세요~~',
#   'cafename': '국준모｜국민건강보험공단,건강보험심...',
#   'cafeurl': 'https://cafe.naver.com/publiccor'},
#  {'title': '르하임 <b>스터디카페</b> 정액권 가격내림',
#   'link': 'http://cafe.naver.com/joonggonara/789704075',
#   'description': '개인거래(판매), 판매중, 가격 60,000원, 직접결제(네이버페이 송금), 르하임 <b>스터디카페</b> 정액권 가격내림, 78시간정도 남았어요. 6만원으로 가격내려서 판매해요. 기간없고, 고등학생 이상부터 출입가능.',
#   'cafename': '중고나라',
#   'cafeurl': 'https://cafe.naver.com/joonggonara'},
#  {'title': '<b>스터디카페</b> 7시30분 도착!',
#   'link': 'http://cafe.naver.com/askjeon/70835',
#   'description': '집공은 도저히 안되서 불안하지만 <b>스터디카페</b> 다닙니다ㅠㅠㅠ 하루종일 마스크끼고 있으니까 확실히 힘들긴 하더라구요.... --------------------------------- 화이팅, 취뽀, 힘내요, 안녕하세요 등 무의미한 게시물 및 도배, 광고성... ',
#   'cafename': '전수환★공기업,공공기관취업,경영학,...',
#   'cafeurl': 'https://cafe.naver.com/askjeon'}]

# %%
listt = []
result = results('스터디카페')
listt = listt+result

file = open('studycafe_cafe.json','w+')
file.write(json.dumps(listt))


df = pd.read_json('studycafe_cafe.json')
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
import re

def clean_html(x):
    x = re.sub("\&\w*\;","",x)
    x = re.sub("<.*?>","",x)
    return x

# %%
df['title'] = df['title'].apply(lambda x: clean_html(x))
df['description'] = df['description'].apply(lambda x: clean_html(x))

# %%
df['title'] = df['title'].apply(lambda x: clean_html(x))
df['description'] = df['description'].apply(lambda x: clean_html(x))

# %%
#df.to_csv('studycafe1.csv',encoding='cp949')
df.to_csv('crawling_cafe.csv',encoding='utf-8-sig',index=False)
